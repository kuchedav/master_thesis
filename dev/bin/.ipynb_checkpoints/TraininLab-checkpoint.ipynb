# %% [markdown]
# # Training Lab

# %%
# install all needed packages
from typing import Tuple
import numpy as np
import os

import skimage.io
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras.activations import softmax
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

from ImageVault import ImageVault

from Utilities import rgb2gray
from Utilities import plot_img

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
# Create objects
img_path = "/Users/davidkuchelmeister/Documents/Studium - Master/Master Thesis/dev/data/swissimage_latest.tif"
imgvault = ImageVault(path=img_path)
imgvault.scale_image(0.5)

map_path = "/Users/davidkuchelmeister/Documents/Studium - Master/Master Thesis/dev/data/pk10krel_2017.tif"
mapvault = ImageVault(path=map_path)

# %%
tile_size = 1000
index_debug = [1,3,4,9]

mapvault.crop_into_tiles(tile_size, tile_index=index_debug)
imgvault.crop_into_tiles(tile_size, tile_index=index_debug)

# %%
# execute convolution
mapvault.exctract_buildings_convolution()

# extract data
mapvault_tile = mapvault.tiles.copy()
building_tile_conv = mapvault.building_tiles_conv.copy()

# %%
Xtest = mapvault_tile
Ytest = building_tile_conv

Xtest_grey = [rgb2gray(i) for i in Xtest]

# %% [markdown]
# ## One picture

# %%
fig, axs = plt.subplots(figsize=(10, 10))
axs.imshow(Xtest[0])

# %% [markdown]
# ## We will cut the picture in 100x100 large pieces to train the CNN on it

# %%
# setup figure
fig, axs = plt.subplots(3,3,figsize=(30, 30))

for i in range(0,9):
    axs[i//3,i%3].imshow(Xtest[0][(i*100):(i*100+100),(i*100):(i*100+100)])

# %% [markdown]
# ##  Define FCN (Fully Convolution Network)
#
# We will create a simple fully convolutional neural network for processing a batch of image patches

# %%
def fcn_no_border(input_height:int, input_width:int) -> keras.Model:
    """
    Create a simple fcn model for semantic segmentation with 47 classes
    
    based on fcn_simple_no_border  from  the notebook 09-FCN for Semantic Segmentation-ML
    """
    nr_of_labels = 47
    model = keras.Sequential()
    
    
    # (used to define input shape on the first layers)
    model.add(keras.layers.Layer(input_shape=(input_height , input_width, 1)))
    
    # add 3 convolutional layers with 3x3 filters
    model.add(keras.layers.Convolution2D(filters=32, kernel_size=3, strides=1, padding='valid', activation='relu'))
    
    model.add(Flatten())
    model.add(Dense(10))
    model.add(Dense(1, activation = "softmax"))
    
    return model

# %%
input_width = 100
input_height = 100

model_fcn = fcn_no_border(input_height, input_width)
model_fcn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy','accuracy'])

model_fcn.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# layer_9 (Layer)              (None, 100, 100, 1)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 98, 98, 32)        320
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 307328)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                3073290
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# ...
# Total params: 3,073,621
# Trainable params: 3,073,621
# Non-trainable params: 0
# _________________________________________________________________

# %%
def cut_into_small_pieces(data):
    return [data[k][i:i+100,j:j+100] \
                for i in range(0,int(Xtest_grey[0].shape[0]/100))\
                for j in range(0,int(Xtest_grey[0].shape[1]/100))\
                for k in range(0,len(data))
            ]

Xtest_grey_small = cut_into_small_pieces(Xtest_grey)
Ytest_small = cut_into_small_pieces(Ytest)

# %%
Xtest_grey_small2 = [i.reshape((100,100,1)) for i in Xtest_grey_small]

# %%
Xtest_grey_small2[0].shape
# Out:
# (100, 100, 1)

# %%
model_fcn.fit(Xtest_grey_small2[0:100],
              Ytest_small[0:100],
              epochs = 10
             )
# Out:
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 100, 100, 1) for input Tensor("layer_input:0", shape=(None, 100, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 100, 1, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-04cd5027995b> in <module>
# ----> 1 model_fcn.fit(Xtest_grey_small2[0:100],
#       2               Ytest_small[0:100],
#       3               epochs = 10
#       4              )
#
# ~/.virtualenvs/master_thesis/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
# ...
